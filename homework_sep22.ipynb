# %%
name = "Prathamesh Joshi"
print(name[0],name[-1])
print(name[0],name[2])
print(name[1+1],name[len(name)-1])
print(name[0+2],name[4-1])
# Out:
# P i
# P a
# a i
# a t

# %%
print(name[0],name[1],name[2],name[3],name[4],name[5],name[6])
print(name[-1],name[len(name)-4])
print(name[len(name)-4],name[len(name)-3])
# Out:
# P r a t h a m
# i o
# o s

# %%
print(name[5+5+1],name[5+5+2])
print(name[len(name)-10],name[len(name)-9],name[len(name)-8],name[len(name)-7])
print(name[len(name)-5-5],name[(len(name)-9)])
# Out:
# J o
# m e s h
# m e
