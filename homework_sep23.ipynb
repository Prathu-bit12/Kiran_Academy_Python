# %%
name  = "Prathamesh"
print(name[::])
print(name[::-1])
print(name[:7:])
print(name[3:6:])
print(name[2:4:])
# Out:
# Prathamesh
# hsemahtarP
# Pratham
# tha
# at

# %%
print(name[::2])
print(name[:8:4])
print(name[-2:len(name):])
print(name[2:6:3])
print(name[4:len(name):5])
# Out:
# Pahms
# Ph
# sh
# aa
# hh

# %%
print(name[-4:-2:1])
print(name[-4:len(name):1])
print(name[-5:-3:])
print(name[4:6:1])
print(name[:3:])
# Out:
# me
# mesh
# am
# ha
# Pra

# %%
print(name[1:3:1])
print(name[:2:])
print(name[4:6:])
print(name[3:7:])
print(name[4:8:1])
# Out:
# ra
# Pr
# ha
# tham
# hame
